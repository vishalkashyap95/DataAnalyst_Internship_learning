# %%
import pandas as pd

# %%
fd = pd.read_excel("final_x_ray_metadata.xlsx")

# %%
fd.loc[9805:9809,'date']
# Out:
# 9805    2020-02-17 00:00:00
# 9806                  Other
# 9807    2020-02-07 00:00:00
# 9808    2020-02-07 00:00:00
# 9809    2020-02-07 00:00:00
# Name: date, dtype: object

# %%
fd.drop(fd[fd.date=='Other'].index,axis='index',inplace=True)

# %%
fd
# Out:
#           id file_id                 date xray_no patient_complaint  \
# 0          1       1  2019-06-28 00:00:00    121X              Pain
# 1          2       2  2019-06-28 00:00:00       4              Pain
# 2          3       3  2019-06-07 00:00:00       2              Pain
# 3          4       4  2019-06-22 00:00:00       6              Pain
# 4          5       5  2019-06-28 00:00:00       8              Pain
# ...      ...     ...                  ...     ...               ...
# 44924  45067   57779  2020-08-03 00:00:00    5097             ADMIT
# 44925  45068   57766  2020-08-03 00:00:00     NaN              PAIN
# 44926  45062   57774  2020-08-03 00:00:00     NaN         CKD ON HD
# 44927  45069   57780  2020-08-03 00:00:00     NaN          Covid 19
# 44928  45070   57781  2020-08-03 00:00:00       4     Fever, cough
#
#          xray_type           created_on          created_by  \
# 0            Chest  2019-06-08 22:39:53       perspicio_cli
# ...

# %%
# !pip install openpyxl
fd.to_excel("final_x_ray_metadata.xlsx",index=False)
# Out:
# ...
#   Stored in directory: C:\Users\No Name\AppData\Local\pip\Cache\wheels\2a\77\35\0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built et-xmlfile
# ...

# %%
fd
# Out:
#           id file_id                 date xray_no patient_complaint  \
# 0          1       1  2019-06-28 00:00:00    121X              Pain
# 1          2       2  2019-06-28 00:00:00       4              Pain
# 2          3       3  2019-06-07 00:00:00       2              Pain
# 3          4       4  2019-06-22 00:00:00       6              Pain
# 4          5       5  2019-06-28 00:00:00       8              Pain
# ...      ...     ...                  ...     ...               ...
# 44924  45067   57779  2020-08-03 00:00:00    5097             ADMIT
# 44925  45068   57766  2020-08-03 00:00:00     NaN              PAIN
# 44926  45062   57774  2020-08-03 00:00:00     NaN         CKD ON HD
# 44927  45069   57780  2020-08-03 00:00:00     NaN          Covid 19
# 44928  45070   57781  2020-08-03 00:00:00       4     Fever, cough
#
#          xray_type           created_on          created_by  \
# 0            Chest  2019-06-08 22:39:53       perspicio_cli
# ...

# %% [markdown]
# ### Which clients create more request
