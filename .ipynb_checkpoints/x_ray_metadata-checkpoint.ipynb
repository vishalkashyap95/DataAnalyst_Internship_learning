# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import missingno as msno
import re
from tqdm import tqdm

# %%
df_x_ray_metdata = pd.read_csv("Table_xraymetadata.csv",encoding='iso-8859-1')

# %%
df_x_ray_metdata.head()
# Out:
#    id  file_id                 date xray_no patient_complaint    xray_type  \
# 0   1        1  2019-06-28 00:00:00    121X              Pain        Chest
# 1   2        2  2019-06-28 00:00:00       4              Pain        Skull
# 2   3        3  2019-06-07 00:00:00       2              Pain  Elbows Both
# 3   4        4  2019-06-22 00:00:00       6              Pain  Wrists Both
# 4   5        5  2019-06-28 00:00:00       8              Pain        Spine
#
#             created_on     created_by           updated_on  updated_by  \
# 0  2019-06-08 22:39:53  perspicio_cli  2019-06-08 22:39:53         NaN
# 1  2019-06-08 22:47:39  perspicio_cli  2019-06-08 22:47:39         NaN
# 2  2019-06-08 22:47:39  perspicio_cli  2019-06-08 22:47:39         NaN
# 3  2019-06-08 22:47:39  perspicio_cli  2019-06-08 22:47:39         NaN
# 4  2019-06-08 22:47:39  perspicio_cli  2019-06-08 22:47:39         NaN
#
#    Deleted_on  Deleted_by  age gender not_repo_comment last_message  \
# 0         NaN         NaN  NaN    NaN              NaN          NaN
# 1         NaN         NaN  NaN    NaN              NaN          NaN
# 2         NaN         NaN  NaN    NaN              NaN          NaN
# 3         NaN         NaN  NaN    NaN              NaN          NaN
# 4         NaN         NaN  NaN    NaN              NaN          NaN
#
#   message_thread center_last_message center_message_thread
# 0            NaN                 NaN                   NaN
# 1            NaN                 NaN                   NaN
# 2            NaN                 NaN                   NaN
# 3            NaN                 NaN                   NaN
# 4            NaN                 NaN                   NaN

# %%
msno.matrix(df_x_ray_metdata)
# Out:
# <AxesSubplot:>

# %%
for i in df_x_ray_metdata.columns:
    if (df_x_ray_metdata[i].isnull().sum()/len(df_x_ray_metdata)*100)>50:
        print("{0}:{1}".format(i,df_x_ray_metdata[i].isnull().sum()/len(df_x_ray_metdata)*100))
# Out:
# updated_by:100.0
# Deleted_on:100.0
# Deleted_by:100.0
# not_repo_comment:99.14314964835752
# last_message:96.98433187928424
# center_last_message:97.55630730882223
# center_message_thread:97.55630730882223

# %%
df_x_ray_metdata.drop(columns=['updated_by','Deleted_on','Deleted_by'],inplace=True)

# %%
len(df_x_ray_metdata.not_repo_comment[df_x_ray_metdata.not_repo_comment.notnull()==True].unique())
# Out:
# 270

# %%
len(df_x_ray_metdata.last_message[df_x_ray_metdata.last_message.notnull()==True].unique())
# Out:
# 844

# %%
df_x_ray_metdata.drop(columns=['center_message_thread','center_last_message','last_message','not_repo_comment'],inplace=True)

# %%
df_x_ray_metdata.gender.isnull().sum()/len(df_x_ray_metdata)
# Out:
# 0.06825870203863617

# %%
df_x_ray_metdata.loc[:,['age','gender','message_thread']]
# Out:
#           age  gender                                     message_thread
# 0         NaN     NaN                                                NaN
# 1         NaN     NaN                                                NaN
# 2         NaN     NaN                                                NaN
# 3         NaN     NaN                                                NaN
# 4         NaN     NaN                                                NaN
# ...       ...     ...                                                ...
# 44927  24 YRS  Female  <div class="msg sysmsg">The File Has Been Repo...
# 44928      70    Male  <div class="msg sysmsg">The File Has Been Repo...
# 44929     28Y    Male  <div class="msg sysmsg">The File Has Been Repo...
# 44930      39  Female  <div class="msg sysmsg">The File Has Been Repo...
# 44931     82Y  Female                                                NaN
#
# [44932 rows x 3 columns]

# %%
[re.sub("\D","",str(i)) for i in df_x_ray_metdata.age if i is not np.NaN]
# Out:
# ['65',
#  '',
#  '',
#  '51',
#  '35',
#  '45',
#  '56',
#  '32',
#  '23',
#  '2713',
#  '36',
#  '32',
#  '28',
#  '65',
#  '66',
#  '50',
#  '48',
#  '68',
#  '45',
#  '60',
#  '23',
#  '6',
#  '69',
#  '47',
#  '32',
#  '69',
#  '47',
#  '28',
#  '89',
#  '89',
#  '80',
#  '57',
#  '82',
#  '70',
#  '38',
#  '79',
#  '71',
#  '43',
#  '53',
#  '57',
#  '57',
#  '57',
#  '79',
#  '25',
#  '35',
#  '60',
#  '84',
#  '50',
#  '25',
#  '20',
#  '6',
#  '23',
#  '24',
#  '6',
#  '15',
#  '82',
#  '3',
#  '21',
#  '32',
#  '66',
#  '42',
#  '49',
#  '51',
#  '62',
#  '61',
#  '32',
#  '48',
#  '1',
#  '50',
#  '50',
#  '12',
#  '48',
#  '35',
#  '68',
#  '68',
#  '52',
#  '73',
#  '29',
#  '51',
#  '17',
#  '65',
#  '76',
#  '40',
#  '28',
#  '30',
#  '82',
#  '60',
#  '52',
#  '60',
#  '38',
#  '25',
#  '78',
#  '72',
#  '24',
#  '38',
#  '82',
#  '35',
#  '38',
#  '38',
#  '38',
#  '38',
#  '38',
#  '70',
#  '12',
#  '40',
#  '2',
#  '27',
#  '27',
#  '27',
#  '60',
#  '32',
#  '80',
#  '17',
#  '24',
#  '58',
#  '19',
#  '19',
#  '48',
#  '22',
#  '40',
#  '32',
#  '40',
#  '27',
#  '35',
#  '45',
#  '45',
#  '3',
#  '8',
#  '2',
#  '71',
#  '7',
#  '3',
#  '16',
#  '38',
#  '65',
#  '60',
#  '51',
#  '82',
#  '27',
#  '74',
#  '38',
#  '70',
#  '70',
#  '70',
#  '8',
#  '8',
#  '63',
#  '7',
#  '24',
#  '40',
#  '33',
#  '77',
#  '17',
#  '50',
#  '32',
#  '26',
#  '48',
#  '48',
#  '48',
#  '36',
#  '23',
#  '22',
#  '35',
#  '69',
#  '35',
#  '35',
#  '37',
#  '35',
#  '82',
#  '23',
#  '2',
#  '17',
#  '33',
#  '2',
#  '61',
#  '7',
#  '72',
#  '72',
#  '58',
#  '40',
#  '25',
#  '21',
#  '60',
#  '65',
#  '35',
#  '38',
#  '29',
#  '52',
#  '45',
#  '58',
#  '17',
#  '45',
#  '5',
#  '47',
#  '82',
#  '60',
#  '46',
#  '61',
#  '85',
#  '85',
#  '31',
#  '59',
#  '59',
#  '91',
#  '22',
#  '25',
#  '45',
#  '21',
#  '34',
#  '18',
#  '63',
#  '20',
#  '21',
#  '28',
#  '55',
#  '52',
#  '25',
#  '42',
#  '14',
#  '56',
#  '52',
#  '42',
#  '21',
#  '39',
#  '39',
#  '39',
#  '52',
#  '35',
#  '35',
#  '23',
#  '63',
#  '4',
#  '75',
#  '25',
#  '34',
#  '29',
#  '10',
#  '64',
#  '22',
#  '46',
#  '46',
#  '30',
#  '45',
#  '38',
#  '91',
#  '60',
#  '45',
#  '25',
#  '9',
#  '65',
#  '50',
#  '7',
#  '6',
#  '61',
#  '61',
#  '19',
#  '23',
#  '5',
#  '12',
#  '25',
#  '35',
#  '64',
#  '63',
#  '71',
#  '43',
#  '58',
#  '58',
#  '31',
#  '63',
#  '63',
#  '59',
#  '55',
#  '78',
#  '3',
#  '30',
#  '62',
#  '85',
#  '36',
#  '15',
#  '45',
#  '60',
#  '32',
#  '54',
#  '26',
#  '6',
#  '32',
#  '21',
#  '15',
#  '15',
#  '29',
#  '29',
#  '29',
#  '38',
#  '15',
#  '67',
#  '32',
#  '57',
#  '68',
#  '42',
#  '44',
#  '29',
#  '26',
#  '18',
#  '18',
#  '28',
#  '26',
#  '65',
#  '39',
#  '25',
#  '215',
#  '50',
#  '76',
#  '64',
#  '39',
#  '18',
#  '30',
#  '45',
#  '30',
#  '32',
#  '58',
#  '66',
#  '40',
#  '17',
#  '44',
#  '30',
#  '38',
#  '27',
#  '2',
#  '41',
#  '21',
#  '3',
#  '23',
#  '24',
#  '35',
#  '24',
#  '8',
#  '60',
#  '32',
#  '29',
#  '67',
#  '31',
#  '50',
#  '26',
#  '21',
#  '15',
#  '30',
#  '8',
#  '23',
#  '45',
#  '00',
#  '83',
#  '30',
#  '30',
#  '24',
#  '76',
#  '76',
#  '63',
#  '63',
#  '63',
#  '78',
#  '50',
#  '27',
#  '67',
#  '22',
#  '58',
#  '72',
#  '40',
#  '7',
#  '5',
#  '48',
#  '67',
#  '60',
#  '29',
#  '45',
#  '47',
#  '56',
#  '48',
#  '48',
#  '20',
#  '16',
#  '62',
#  '3',
#  '35',
#  '34',
#  '35',
#  '65',
#  '74',
#  '67',
#  '67',
#  '62',
#  '70',
#  '40',
#  '35',
#  '31',
#  '31',
#  '31',
#  '50',
#  '38',
#  '57',
#  '65',
#  '20',
#  '14',
#  '64',
#  '29',
#  '28',
#  '26',
#  '56',
#  '56',
#  '56',
#  '24',
#  '52',
#  '55',
#  '21',
#  '52',
#  '34',
#  '52',
#  '37',
#  '14',
#  '25',
#  '75',
#  '75',
#  '21',
#  '51',
#  '29',
#  '60',
#  '27',
#  '15',
#  '29',
#  '38',
#  '50',
#  '2',
#  '41',
#  '1',
#  '45',
#  '75',
#  '75',
#  '63',
#  '65',
#  '53',
#  '40',
#  '33',
#  '32',
#  '35',
#  '15',
#  '42',
#  '42',
#  '42',
#  '96',
#  '96',
#  '7',
#  '14',
#  '65',
#  '55',
#  '29',
#  '22',
#  '35',
#  '40',
#  '28',
#  '60',
#  '24',
#  '26',
#  '58',
#  '58',
#  '20',
#  '1',
#  '22',
#  '31',
#  '31',
#  '31',
#  '44',
#  '76',
#  '35',
#  '55',
#  '19',
#  '50',
#  '17',
#  '69',
#  '69',
#  '44',
#  '60',
#  '212',
#  '9',
#  '28',
#  '28',
#  '7',
#  '50',
#  '72',
#  '46',
#  '45',
#  '63',
#  '66',
#  '65',
#  '31',
#  '31',
#  '31',
#  '65',
#  '32',
#  '32',
#  '18',
#  '27',
#  '36',
#  '10',
#  '43',
#  '3',
#  '2',
#  '22',
#  '23',
#  '56',
#  '65',
#  '60',
#  '84',
#  '55',
#  '35',
#  '36',
#  '38',
#  '48',
#  '48',
#  '30',
#  '35',
#  '2',
#  '81',
#  '42',
#  '22',
#  '63',
#  '52',
#  '27',
#  '76',
#  '49',
#  '4',
#  '35',
#  '55',
#  '18',
#  '22',
#  '22',
#  '35',
#  '40',
#  '12',
#  '18',
#  '20',
#  '58',
#  '63',
#  '32',
#  '41',
#  '62',
#  '61',
#  '25',
#  '60',
#  '28',
#  '55',
#  '26',
#  '48',
#  '59',
#  '33',
#  '10',
#  '42',
#  '26',
#  '72',
#  '47',
#  '47',
#  '50',
#  '35',
#  '58',
#  '40',
#  '16',
#  '50',
#  '46',
#  '46',
#  '2',
#  '68',
#  '39',
#  '22',
#  '28',
#  '24',
#  '42',
#  '55',
#  '46',
#  '34',
#  '34',
#  '34',
#  '39',
#  '39',
#  '54',
#  '35',
#  '40',
#  '19',
#  '64',
#  '48',
#  '52',
#  '64',
#  '62',
#  '69',
#  '61',
#  '60',
#  '35',
#  '26',
#  '68',
#  '28',
#  '76',
#  '51',
#  '79',
#  '64',
#  '60',
#  '67',
#  '67',
#  '1',
#  '24',
#  '44',
#  '33',
#  '78',
#  '13',
#  '40',
#  '60',
#  '60',
#  '62',
#  '33',
#  '27',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '30',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '26',
#  '50',
#  '50',
#  '50',
#  '50',
#  '50',
#  '30',
#  '30',
#  '30',
#  '50',
#  '17',
#  '',
#  '',
#  '',
#  '23',
#  '32',
#  '21',
#  '45',
#  '76',
#  '61',
#  '65',
#  '3',
#  '6',
#  '11',
#  '12',
#  '9',
#  '68',
#  '24',
#  '17',
#  '17',
#  '17',
#  '3',
#  '55',
#  '28',
#  '76',
#  '50',
#  '50',
#  '49',
#  '69',
#  '29',
#  '55',
#  '72',
#  '55',
#  '18',
#  '18',
#  '13',
#  '46',
#  '64',
#  '55',
#  '70',
#  '17',
#  '17',
#  '17',
#  '34',
#  '37',
#  '70',
#  '70',
#  '22',
#  '44',
#  '39',
#  '17',
#  '15',
#  '34',
#  '24',
#  '17',
#  '16',
#  '26',
#  '55',
#  '33',
#  '19',
#  '3',
#  '36',
#  '36',
#  '17',
#  '86',
#  '37',
#  '35',
#  '26',
#  '69',
#  '33',
#  '16',
#  '41',
#  '65',
#  '63',
#  '45',
#  '17',
#  '23',
#  '18',
#  '5',
#  '38',
#  '60',
#  '45',
#  '61',
#  '42',
#  '42',
#  '61',
#  '12',
#  '61',
#  '11',
#  '42',
#  '46',
#  '46',
#  '46',
#  '58',
#  '65',
#  '56',
#  '45',
#  '37',
#  '35',
#  '48',
#  '61',
#  '57',
#  '21',
#  '60',
#  '78',
#  '30',
#  '18',
#  '10',
#  '9',
#  '12',
#  '45',
#  '34',
#  '61',
#  '44',
#  '30',
#  '36',
#  '22',
#  '55',
#  '52',
#  '60',
#  '22',
#  '63',
#  '63',
#  '40',
#  '48',
#  '55',
#  '22',
#  '55',
#  '19',
#  '49',
#  '70',
#  '30',
#  '10',
#  '55',
#  '27',
#  '23',
#  '32',
#  '79',
#  '33',
#  '68',
#  '65',
#  '27',
#  '24',
#  '56',
#  '38',
#  '38',
#  '71',
#  '49',
#  '38',
#  '60',
#  '78',
#  '33',
#  '91',
#  '91',
#  '91',
#  '25',
#  '35',
#  '12',
#  '65',
#  '65',
#  '25',
#  '60',
#  '17',
#  '39',
#  '26',
#  '39',
#  '33',
#  '50',
#  '72',
#  '27',
#  '45',
#  '37',
#  '59',
#  '21',
#  '23',
#  '25',
#  '12',
#  '46',
#  '40',
#  '80',
#  '36',
#  '62',
#  '62',
#  '26',
#  '36',
#  '65',
#  '23',
#  '18',
#  '55',
#  '21',
#  '50',
#  '17',
#  '30',
#  '30',
#  '71',
#  '29',
#  '38',
#  '30',
#  '45',
#  '36',
#  '69',
#  '30',
#  '24',
#  '56',
#  '32',
#  '69',
#  '56',
#  '61',
#  '23',
#  '36',
#  '76',
#  '39',
#  '59',
#  '8',
#  '59',
#  '52',
#  '70',
#  '69',
#  '30',
#  '50',
#  '21',
#  '53',
#  '39',
#  '63',
#  '11',
#  '64',
#  '40',
#  '34',
#  '62',
#  '62',
#  '18',
#  '13',
#  '21',
#  '3',
#  '20',
#  '30',
#  '38',
#  '83',
#  '83',
#  '83',
#  '32',
#  '65',
#  '82',
#  '39',
#  '45',
#  '70',
#  '55',
#  '9',
#  '68',
#  '44',
#  '42',
#  '42',
#  '17',
#  '8',
#  '41',
#  '41',
#  '28',
#  '25',
#  '63',
#  '45',
#  '45',
#  '21',
#  '00',
#  '00',
#  '00',
#  '00',
#  '53',
#  '70',
#  '22',
#  '21',
#  '45',
#  '11',
#  '65',
#  '33',
#  '37',
#  '60',
#  '24',
#  '6',
#  '60',
#  '30',
#  '60',
#  '52',
#  '44',
#  '50',
#  '21',
#  '35',
#  '62',
#  '62',
#  '29',
#  '36',
#  '58',
#  '24',
#  '37',
#  '43',
#  '49',
#  '75',
#  '82',
#  '83',
#  '',
#  '20',
#  '74',
#  '32',
#  '25',
#  '41',
#  '10',
#  '45',
#  '21',
#  '8',
#  '47',
#  '50',
#  '47',
#  '47',
#  '44',
#  '56',
#  '56',
#  '56',
#  '53',
#  '38',
#  '15',
#  '36',
#  '42',
#  '26',
#  '65',
#  '52',
#  '35',
#  '61',
#  '75',
#  '50',
#  '9',
#  '32',
#  '29',
#  '34',
#  '14',
#  '38',
#  '46',
#  '30',
#  '2',
#  '37',
#  '32',
#  '32',
#  '8',
#  '18',
#  '66',
#  '37',
#  '35',
#  '60',
#  '63',
#  '50',
#  '39',
#  '37',
#  '67',
#  '16',
#  '35',
#  ...]

# %%
df_x_ray_metdata.age = df_x_ray_metdata.age.apply(lambda x :re.sub("\D","",str(x)) if x is not np.NaN else -1)

# %%
msno.matrix(df_x_ray_metdata)
# Out:
# <AxesSubplot:>

# %%
import random
print(random.randrange(0,2))
# Out:
# 1

# %%
for i in tqdm(range(0,len(df_x_ray_metdata))):
    randomNo = random.randrange(0,2)
    if df_x_ray_metdata.gender[i] is np.NaN:
        if randomNo is 0:
            df_x_ray_metdata.loc[i,'gender']='Male'
        else:
            df_x_ray_metdata.loc[i,'gender']='Female'
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 44932/44932 [00:06<00:00, 7034.84it/s]

# %%
df_x_ray_metdata.gender.value_counts()
# Out:
# Male      24694
# Female    20178
# Other        60
# Name: gender, dtype: int64

# %%
# len(df_x_ray_metdata[df_x_ray_metdata.loc[:,'gender']=='Other'])
# df_x_ray_metdata[df_x_ray_metdata.loc[:,'gender']=='O']='Other'
# Out:
# 60

# %%
df_x_ray_metdata.isnull().sum()[df_x_ray_metdata.isnull().sum()>0]
# Out:
# date                    3
# patient_complaint    2685
# message_thread       9899
# dtype: int64

# %%
df_x_ray_metdata.xray_type.fillna("N/A",inplace=True)

# %%
df_x_ray_metdata.xray_type.isna().sum()
# Out:
# 0

# %%
df_x_ray_metdata.xray_no.fillna("N/A",inplace=True)

# %%
df_x_ray_metdata.xray_no.isna().sum()
# Out:
# 0

# %%
df_x_ray_metdata
# Out:
#           id file_id                 date xray_no patient_complaint  \
# 0          1       1  2019-06-28 00:00:00    121X              Pain
# 1          2       2  2019-06-28 00:00:00       4              Pain
# 2          3       3  2019-06-07 00:00:00       2              Pain
# 3          4       4  2019-06-22 00:00:00       6              Pain
# 4          5       5  2019-06-28 00:00:00       8              Pain
# ...      ...     ...                  ...     ...               ...
# 44927  45067   57779  2020-08-03 00:00:00    5097             ADMIT
# 44928  45068   57766  2020-08-03 00:00:00     N/A              PAIN
# 44929  45062   57774  2020-08-03 00:00:00     N/A         CKD ON HD
# 44930  45069   57780  2020-08-03 00:00:00     N/A          Covid 19
# 44931  45070   57781  2020-08-03 00:00:00       4     Fever, cough
#
#          xray_type           created_on          created_by  \
# 0            Chest  2019-06-08 22:39:53       perspicio_cli
# 1            Skull  2019-06-08 22:47:39       perspicio_cli
# 2      Elbows Both  2019-06-08 22:47:39       perspicio_cli
# 3      Wrists Both  2019-06-08 22:47:39       perspicio_cli
# 4            Spine  2019-06-08 22:47:39       perspicio_cli
# ...            ...                  ...                 ...
# 44927   Hand Right  2020-08-03 11:12:20          Chamunda_1
# 44928     Chest PA  2020-08-03 11:34:52                SK_1
# 44929     Chest PA  2020-08-03 11:07:09  Mallika_Hospital_1
# 44930     Chest PA  2020-08-03 11:41:00            Shakti_1
# 44931     Chest AP  2020-08-03 12:10:15             Sneha_1
#
#                 updated_on age  gender  \
# 0      2019-06-08 22:39:53  -1  Female
# 1      2019-06-08 22:47:39  -1  Female
# 2      2019-06-08 22:47:39  -1    Male
# 3      2019-06-08 22:47:39  -1  Female
# 4      2019-06-08 22:47:39  -1  Female
# ...                    ...  ..     ...
# 44927  2020-08-03 11:48:56  24  Female
# 44928  2020-08-03 11:50:02  70    Male
# 44929  2020-08-03 11:50:31  28    Male
# 44930  2020-08-03 11:51:21  39  Female
# 44931  2020-08-03 12:10:15  82  Female
#
#                                           message_thread
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44927  <div class="msg sysmsg">The File Has Been Repo...
# 44928  <div class="msg sysmsg">The File Has Been Repo...
# 44929  <div class="msg sysmsg">The File Has Been Repo...
# 44930  <div class="msg sysmsg">The File Has Been Repo...
# 44931                                                NaN
#
# [44932 rows x 12 columns]

# %%
df_x_ray_metdata.iloc[1553:1556]
# Out:
#         id file_id                 date xray_no      patient_complaint  \
# 1553  1560    3356  2019-09-16 00:00:00     N/A  FEVER,DENGUE POSITIVE
# 1555  1562    3359  2019-09-18 00:00:00     N/A           DENGUE FEVER
# 1556  1563    3360  2019-09-19 00:00:00     N/A           DENGUE FEVER
#
#      xray_type           created_on      created_by           updated_on age  \
# 1553     Chest  2019-09-20 10:19:09  DNA_Hospital_1  2019-09-20 10:19:09  -1
# 1555     Chest  2019-09-20 10:19:09  DNA_Hospital_1  2019-09-20 10:19:09  -1
# 1556     Chest  2019-09-20 10:23:43  DNA_Hospital_1  2019-09-20 10:23:43  -1
#
#       gender message_thread
# 1553  Female            NaN
# 1555  Female            NaN
# 1556  Female            NaN

# %%
df_x_ray_metdata.drop([34190,42337],axis='index',inplace=True)

# %%
df_x_ray_metdata[df_x_ray_metdata['date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, file_id, date, xray_no, patient_complaint, xray_type, created_on, created_by, updated_on, age, gender, message_thread]
# Index: []
